# %% [markdown]
# <a href="https://colab.research.google.com/github/Venchislav/Stats-for-DS/blob/main/diamond_bar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('/content/diamonds.csv')
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
crosstab = pd.crosstab(df['clarity'], df['cut'])
crosstab
# Out:
# cut      Fair  Good  Ideal  Premium  Very Good
# clarity
# I1        210    96    146      205         84
# IF          9    71   1212      230        268
# SI1       408  1560   4282     3575       3240
# SI2       466  1081   2598     2949       2100
# VS1       170   648   3589     1989       1775
# VS2       261   978   5071     3357       2591
# VVS1       17   186   2047      616        789
# VVS2       69   286   2606      870       1235

# %%
crosstab.plot(kind='bar')
# Out:
# <Axes: xlabel='clarity'>

# %%
crosstab = pd.crosstab(df['color'], df['cut'])
crosstab
# Out:
# cut    Fair  Good  Ideal  Premium  Very Good
# color
# D       163   662   2834     1603       1513
# E       224   933   3903     2337       2400
# F       312   909   3826     2331       2164
# G       314   871   4884     2924       2299
# H       303   702   3115     2360       1824
# I       175   522   2093     1428       1204
# J       119   307    896      808        678

# %%
crosstab.plot(kind='bar')
# Out:
# <Axes: xlabel='color'>
