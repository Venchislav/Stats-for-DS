# %% [markdown]
# <a href="https://colab.research.google.com/github/Venchislav/Stats-for-DS/blob/main/AvocadoPd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn import linear_model
from warnings import simplefilter
import matplotlib.pyplot as plt

# %%
# ignore all warnings
simplefilter(action='ignore')

# %%
df = pd.read_csv('/content/avocado.csv')
df['year'].head()
# Out:
# 0    2015
# 1    2015
# 2    2015
# 3    2015
# 4    2015
# Name: year, dtype: int64

# %%
X = df[['year']]
y = df['AveragePrice']

regr = linear_model.LinearRegression()
regr.fit(X, y)
# Out:
# LinearRegression()

# %%
for i in range(2023, 100000, 5000):
  print(f'{i}: {regr.predict([[i]])[0]}$')
# Out:
# 2023: 1.6795572882245011$
# 7023: 201.31092515909427$
# 12023: 400.942293029964$
# 17023: 600.5736609008337$
# 22023: 800.2050287717035$
# 27023: 999.8363966425733$
# 32023: 1199.467764513443$
# 37023: 1399.0991323843127$
# 42023: 1598.7305002551825$
# 47023: 1798.3618681260523$
# 52023: 1997.993235996922$
# 57023: 2197.624603867792$
# 62023: 2397.2559717386616$
# 67023: 2596.8873396095314$
# 72023: 2796.518707480401$
# 77023: 2996.150075351271$
# 82023: 3195.7814432221408$
# 87023: 3395.4128110930105$
# 92023: 3595.0441789638803$
# 97023: 3794.6755468347496$

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
plt.bar(df['Date'][0:500:100], df['AveragePrice'][0:500:100])
plt.xticks(df['Date'][0:500:100].unique())
# Out:
# ([<matplotlib.axis.XTick at 0x7a7404889540>,
# ...
#  [Text(0.0, 0, '2015-12-27'),
#   Text(1.0, 0, '2015-01-25'),
#   Text(2.0, 0, '2015-02-22'),
#   Text(3.0, 0, '2015-03-22'),
#   Text(4.0, 0, '2015-04-19')])

# %%
plt.bar(df['year'], df['AveragePrice'])
plt.xticks(df['year'].unique())
# Out:
# ([<matplotlib.axis.XTick at 0x7a74047cc580>,
# ...
#  [Text(2015, 0, '2015'),
#   Text(2016, 0, '2016'),
#   Text(2017, 0, '2017'),
#   Text(2018, 0, '2018')])

# %% [markdown]
# And I'm not sure that my code is correct. I don't have enough experience, but as prediction says: avocados will cost more in the future (about 320$ each in year 9999) so it's a good investment I guess.
#
# ![926e5009-c10a-48fe-b90e-fa0760f82fcd.png](data:image/png;base64,...)
